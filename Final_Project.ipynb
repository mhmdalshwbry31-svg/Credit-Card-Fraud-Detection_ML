# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.preprocessing import StandardScaler


from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,r2_score,roc_auc_score,RocCurveDisplay,ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, f1_score

# %% [markdown]
# # Reading & Reshaping The Data

# %%
df_full = pd.read_csv("creditcard.csv")

sample_size = 15000
fraud_ratio = 0.03
fraud_count = int(sample_size * fraud_ratio)
normal_count = sample_size - fraud_count
random_state = 42

fraud_sample = df_full[df_full["Class"] == 1].sample(
    n=fraud_count,
    replace=fraud_count > (df_full["Class"] == 1).sum(),
    random_state=random_state
)
normal_sample = df_full[df_full["Class"] == 0].sample(n=normal_count, random_state=random_state)

df = pd.concat([fraud_sample, normal_sample], ignore_index=True)
df = df.sample(frac=1, random_state=random_state).reset_index(drop=True)

print(df.shape)
print(df["Class"].value_counts())
print(df["Class"].value_counts(normalize=True) * 100)
# Out:
# (15000, 31)
# Class
# 0    14550
# 1      450
# Name: count, dtype: int64
# Class
# 0    97.0
# 1     3.0
# Name: proportion, dtype: float64

# %% [markdown]
# # Data Investigation

# %%
df.shape
# Out:
# (15000, 31)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    15000 non-null  float64
#  1   V1      15000 non-null  float64
#  2   V2      15000 non-null  float64
#  3   V3      15000 non-null  float64
#  4   V4      15000 non-null  float64
#  5   V5      15000 non-null  float64
#  6   V6      15000 non-null  float64
#  7   V7      15000 non-null  float64
#  8   V8      15000 non-null  float64
#  9   V9      15000 non-null  float64
#  10  V10     15000 non-null  float64
#  11  V11     15000 non-null  float64
#  12  V12     15000 non-null  float64
#  13  V13     15000 non-null  float64
#  14  V14     15000 non-null  float64
#  15  V15     15000 non-null  float64
#  16  V16     15000 non-null  float64
#  17  V17     15000 non-null  float64
#  18  V18     15000 non-null  float64
#  19  V19     15000 non-null  float64
#  20  V20     15000 non-null  float64
#  21  V21     15000 non-null  float64
#  22  V22     15000 non-null  float64
#  23  V23     15000 non-null  float64
#  24  V24     15000 non-null  float64
#  25  V25     15000 non-null  float64
#  26  V26     15000 non-null  float64
#  27  V27     15000 non-null  float64
#  28  V28     15000 non-null  float64
#  29  Amount  15000 non-null  float64
#  30  Class   15000 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 3.5 MB

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count   15000.000000  15000.000000  15000.000000  15000.000000  15000.000000
# mean    94685.601467     -0.127226      0.105085     -0.216090      0.123470
# std     47472.681430      2.358191      1.839971      2.227167      1.652035
# min         0.000000    -30.552380    -32.494845    -31.103685     -4.938824
# 25%     54409.750000     -0.954512     -0.586813     -1.018264     -0.816403
# 50%     84976.500000     -0.003432      0.087175      0.116673      0.021128
# 75%    139139.500000      1.303224      0.860411      0.985389      0.825526
# max    172768.000000      2.398119     22.057729      3.770236     11.906170
#
#                  V5            V6            V7            V8            V9  \
# count  15000.000000  15000.000000  15000.000000  15000.000000  15000.000000
# mean      -0.074528     -0.046353     -0.169445      0.023412     -0.056573
# std        1.690446      1.362707      1.926509      1.627986      1.249462
# min      -22.105532    -17.282140    -43.557242    -41.044261    -13.434066
# 25%       -0.708259     -0.799760     -0.604359     -0.204568     -0.675899
# 50%       -0.061710     -0.294764      0.019296      0.026491     -0.056026
# 75%        0.629130      0.386568      0.569782      0.350819      0.600701
# max       28.516513     15.323769     15.915767     20.007208      7.929051
#
#        ...           V21           V22           V23           V24  \
# count  ...  15000.000000  15000.000000  15000.000000  15000.000000
# mean   ...      0.018872      0.001349     -0.001416     -0.005875
# std    ...      0.980881      0.755245      0.646074      0.610759
# min    ...    -22.797604     -8.887017    -19.254328     -2.836627
# 25%    ...     -0.223291     -0.545677     -0.165963     -0.356566
# 50%    ...     -0.022551      0.009803     -0.010047      0.036833
# 75%    ...      0.195462      0.527567      0.154336      0.433143
# max    ...     27.202839      8.361985     15.626067      4.016342
#
#                 V25           V26           V27           V28        Amount  \
# count  15000.000000  15000.000000  15000.000000  15000.000000  15000.000000
# mean      -0.006784      0.003314      0.005480      0.003711     87.513799
# std        0.531213      0.483708      0.461721      0.342022    227.313623
# min       -4.781606     -1.581931     -9.543518     -8.307955      0.000000
# 25%       -0.324105     -0.327020     -0.069713     -0.052208      4.990000
# 50%        0.012000     -0.042159      0.003236      0.011971     21.000000
# 75%        0.348877      0.253821      0.099948      0.082582     76.442500
# max        5.541598      3.039297      9.879903     15.870474   6511.000000
#
#               Class
# count  15000.000000
# mean       0.030000
# std        0.170593
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 31 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(20)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# Time
# 48601.0     5
# 41273.0     3
# 146998.0    3
# 37187.0     3
# 93879.0     3
#            ..
# 81579.0     1
# 137908.0    1
# 22396.0     1
# 167609.0    1
# 39737.0     1
# Name: count, Length: 14229, dtype: int64
# V1
#  2.055797    7
#  1.245674    5
#  2.085175    3
#  1.302378    3
#  1.012595    3
#             ..
#  1.519406    1
#  1.378933    1
# -0.199324    1
# -1.078759    1
#  1.099987    1
# Name: count, Length: 14923, dtype: int64
# V2
# -0.326668    7
#  0.166975    5
#  0.393051    3
# -0.606529    3
#  0.185411    3
#             ..
# -0.931312    1
# -0.411443    1
#  1.170036    1
#  0.257122    1
# -0.233236    1
# Name: count, Length: 14923, dtype: int64
# V3
# -2.752041    7
#  0.488306    5
# -4.508201    3
# -0.681986    3
#  1.857002    3
#             ..
# -0.818590    1
#  0.679079    1
# -0.202227    1
#  0.961346    1
#  1.117423    1
# Name: count, Length: 14923, dtype: int64
# V4
# -0.842316    7
#  0.635322    5
# -0.311771    3
# -1.904603    3
#  2.625675    3
#             ..
#  1.169195    1
# -0.508045    1
# -0.574850    1
# -0.753251    1
#  0.684984    1
# Name: count, Length: 14923, dtype: int64
# V5
#  2.463072    7
# -0.562777    5
#  3.510117    3
#  1.326623    3
# -0.813686    3
#             ..
# -0.252038    1
# -0.937701    1
#  1.177252    1
#  0.152068    1
# -0.794438    1
# Name: count, Length: 14923, dtype: int64
# V6
#  3.173856    7
# -1.011073    5
#  2.453299    3
#  3.436312    3
#  0.741198    3
#             ..
#  0.568912    1
# -0.560701    1
# -1.327164    1
#  1.633332    1
#  0.250720    1
# Name: count, Length: 14923, dtype: int64
# V7
# -0.432126    7
#  0.014953    5
#  0.220469    3
# -1.145127    3
# -1.050510    3
#             ..
# -0.337546    1
# -0.788391    1
#  1.404584    1
# -0.413298    1
# -0.608037    1
# Name: count, Length: 14923, dtype: int64
# V8
#  0.727706    7
# -0.160211    5
#  0.543377    3
#  0.959147    3
#  0.411449    3
#             ..
#  0.150867    1
# -0.083985    1
# -0.668156    1
#  1.078941    1
#  0.162827    1
# Name: count, Length: 14923, dtype: int64
# V9
#  0.608606    7
#  0.170362    5
# -0.100434    3
#  1.671302    3
#  1.078229    3
#             ..
#  0.643885    1
#  0.647096    1
# -0.023714    1
# -1.652741    1
#  0.502647    1
# Name: count, Length: 14923, dtype: int64
# V10
# -0.075186    7
# -0.044575    5
# -1.018622    3
# -1.022946    3
#  0.410744    3
#             ..
#  0.280503    1
#  0.226090    1
# -0.803370    1
#  0.110098    1
# -0.122215    1
# Name: count, Length: 14923, dtype: int64
# V11
#  0.063504    7
# -0.356749    5
#  0.807038    3
# -0.191423    3
#  2.237912    3
#             ..
#  0.277004    1
#  0.831754    1
# -0.459820    1
#  1.483839    1
#  0.883891    1
# Name: count, Length: 14923, dtype: int64
# V12
#  0.350564    7
# -0.073460    5
# -0.330548    3
#  0.631027    3
# -2.310506    3
#             ..
#  0.725810    1
# -3.455321    1
#  0.032423    1
#  1.267197    1
#  1.679554    1
# Name: count, Length: 14923, dtype: int64
# V13
# -0.141238    7
# -0.517760    5
# -0.531419    3
#  0.031907    3
#  0.771152    3
#             ..
#  0.186176    1
#  0.872082    1
#  0.802857    1
#  0.446386    1
#  1.258640    1
# Name: count, Length: 14923, dtype: int64
# V14
#  0.690972    7
#  0.406969    5
# -2.181449    3
# -0.031425    3
#  1.647488    3
#             ..
#  0.204410    1
#  1.493260    1
# -1.372168    1
#  0.282548    1
# -0.468718    1
# Name: count, Length: 14923, dtype: int64
# V15
#  1.275257    7
#  1.124147    5
#  0.388724    3
#  1.446627    3
#  0.005918    3
#             ..
#  0.187744    1
#  0.429744    1
#  0.355900    1
# -0.368157    1
# -0.608084    1
# Name: count, Length: 14923, dtype: int64
# V16
# -0.371962    7
#  0.342470    5
#  0.232071    3
# -0.121820    3
#  1.168256    3
#             ..
#  0.869786    1
#  0.956378    1
#  0.090245    1
# -2.992761    1
#  0.401315    1
# Name: count, Length: 14923, dtype: int64
# V17
# -0.601957    7
# -0.374656    5
#  2.125022    3
# -0.651405    3
# -0.044722    3
#             ..
# -1.251628    1
#  1.281936    1
#  0.134884    1
#  1.439859    1
# -0.614085    1
# Name: count, Length: 14923, dtype: int64
# V18
# -0.052640    7
# -0.438992    5
#  0.405549    3
#  0.617970    3
#  0.838389    3
#             ..
#  1.097645    1
# -1.644284    1
#  0.606847    1
# -0.620068    1
#  0.221697    1
# Name: count, Length: 14923, dtype: int64
# V19
# -0.330590    7
# -0.116091    5
# -0.440930    3
#  0.927600    3
# -1.766324    3
#             ..
# -0.332994    1
#  0.054734    1
# -0.521992    1
# -1.670109    1
#  0.354076    1
# Name: count, Length: 14923, dtype: int64
# V20
# -0.180370    7
# -0.132080    5
# -0.086989    3
#  0.005757    3
# -0.240469    3
#             ..
#  0.276386    1
# -0.080643    1
# -0.073344    1
# -0.447958    1
#  0.066401    1
# Name: count, Length: 14923, dtype: int64
# V21
#  0.269765    7
# -0.262581    5
# -0.067217    3
# -0.064208    3
#  0.167722    3
#             ..
#  0.374596    1
# -0.232954    1
#  0.305408    1
# -0.215744    1
# -0.027821    1
# Name: count, Length: 14923, dtype: int64
# V22
#  0.844627    7
# -0.816264    5
# -0.072642    3
# -0.080587    3
#  0.665253    3
#             ..
#  0.642561    1
# -0.540031    1
#  1.135777    1
#  0.046397    1
#  0.065863    1
# Name: count, Length: 14923, dtype: int64
# V23
#  0.020675    7
#  0.140304    5
# -0.036584    3
# -0.072991    3
#  0.034227    3
#             ..
# -0.107051    1
#  0.193555    1
# -0.349744    1
#  0.114858    1
# -0.064771    1
# Name: count, Length: 14923, dtype: int64
# V24
#  0.726212    7
#  0.357827    5
#  0.529693    3
#  1.018136    3
#  0.149377    3
#             ..
#  0.188902    1
# -0.039360    1
# -0.154930    1
# -0.998933    1
#  0.087285    1
# Name: count, Length: 14923, dtype: int64
# V25
#  0.366624    7
#  0.186423    5
#  0.414685    3
#  0.663575    3
#  0.061452    3
#             ..
# -0.113449    1
#  0.104644    1
# -0.451053    1
# -0.457318    1
#  0.298087    1
# Name: count, Length: 14923, dtype: int64
# V26
# -0.398828    7
#  0.096544    5
#  0.735870    3
# -0.671323    3
#  0.073725    3
#             ..
# -0.606737    1
# -0.486110    1
# -0.291200    1
#  0.420201    1
#  0.311691    1
# Name: count, Length: 14923, dtype: int64
# V27
#  0.027735    7
# -0.035866    5
# -0.058233    3
#  0.096801    3
#  0.024623    3
#             ..
#  0.004086    1
# -0.004816    1
# -0.196551    1
#  0.298831    1
#  0.014591    1
# Name: count, Length: 14923, dtype: int64
# V28
# -0.060282    7
#  0.018495    5
# -0.026658    3
#  0.028697    3
#  0.023365    3
#             ..
#  0.001718    1
#  0.009625    1
#  0.020524    1
#  0.081741    1
#  0.022126    1
# Name: count, Length: 14923, dtype: int64
# Amount
# 1.00       812
# 1.98       301
# 0.89       271
# 9.99       245
# 0.76       168
#           ...
# 251.95       1
# 49.32        1
# 73.80        1
# 1706.35      1
# 41.33        1
# Name: count, Length: 5698, dtype: int64
# Class
# 0    14548
# 1      432
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
df.hist(figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(20,15))
corr = df.corr()
labaled_corr = corr[["Class"]].sort_values("Class",ascending=False)
sns.heatmap(labaled_corr,annot=True,cmap="YlGnBu")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='str')

# %%
df= df.drop([ 'V13', 'V15', 'V22', 'V23', 'V25', 'V26'],axis=1)

# %%
df["Class"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Checking for outliers in the "Amount" col.

# %%
q1 = df["Amount"].quantile(0.25)
q3 = df["Amount"].quantile(0.75)

iqr = q3-q1
upper = q3+1.5*iqr
lower = q1-1.5*iqr
outliers = ((df["Amount"]<lower)|(df["Amount"]>upper))
num_outlier = outliers.sum()
print("number of outlier rows : ",num_outlier)
print("the percentage of the outlier rows : ",num_outlier/len(df))
# Out:
# number of outlier rows :  1707
# the percentage of the outlier rows :  0.11395193591455274

# %%
df["Amount"].describe()
# Out:
# count    14980.000000
# mean        87.531432
# std        227.411517
# min          0.000000
# 25%          5.000000
# 50%         21.005000
# 75%         76.442500
# max       6511.000000
# Name: Amount, dtype: float64

# %% [markdown]
# # Splitting The Data

# %%
x = df.drop(columns = "Class")
y = df["Class"]

# %%
x_train,x_test,y_train,y_test = train_test_split(
    x,
    y,
    test_size=0.25,
    random_state = 42

)

# %%
x_train = pd.DataFrame(x_train,columns=x.columns)
x_test = pd.DataFrame(x_test,columns=x.columns)

# %%
x_train.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V14', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V24',
#        'V27', 'V28', 'Amount'],
#       dtype='str')

# %%
x_test.shape
# Out:
# (3745, 24)

# %%
y_train.value_counts()
# Out:
# Class
# 0    10911
# 1      324
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# Class
# 0    3637
# 1     108
# Name: count, dtype: int64

# %% [markdown]
# # Capping the outliers in the "Amount"

# %%
q1 = x_train['Amount'].quantile(0.25)
q3 = x_train['Amount'].quantile(0.75)
iqr = q3 - q1

lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr

x_train['Amount'] = x_train['Amount'].clip(lower=lower_fence, upper=upper_fence)
x_test['Amount'] = x_test['Amount'].clip(lower=lower_fence, upper=upper_fence)

# %%
x_train["Amount"].describe()
# Out:
# count    11235.000000
# mean        51.191926
# std         61.435106
# min          0.000000
# 25%          5.000000
# 50%         21.000000
# 75%         76.370000
# max        183.425000
# Name: Amount, dtype: float64

# %%
x_test["Amount"].describe()
# Out:
# count    3745.000000
# mean       51.635686
# std        62.159449
# min         0.000000
# 25%         4.940000
# 50%        21.090000
# 75%        77.050000
# max       183.425000
# Name: Amount, dtype: float64

# %% [markdown]
# # Applying Standardization for "Time" & "Amount"

# %%
scaler_amount = StandardScaler()
scaler_time = StandardScaler()


x_train['scaled_amount'] = scaler_amount.fit_transform(x_train[['Amount']])
x_train['scaled_time'] = scaler_time.fit_transform(x_train[['Time']])

x_test['scaled_amount'] = scaler_amount.transform(x_test[['Amount']])
x_test['scaled_time'] = scaler_time.transform(x_test[['Time']])

# %%
print("x_train :",x_train.shape)
print("x_test :",x_test.shape)
# Out:
# x_train : (11235, 26)
# x_test : (3745, 26)

# %%
x_train.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V14', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V24',
#        'V27', 'V28', 'Amount', 'scaled_amount', 'scaled_time'],
#       dtype='str')

# %% [markdown]
# # SVC Model

# %%
svc = SVC(kernel='sigmoid',C=0.1,degree=2,random_state=42,probability=True)
svc.fit(x_train,y_train)
# Out:
# C:\Users\Mahmoud\AppData\Roaming\Python\Python314\site-packages\sklearn\svm\_base.py:239: FutureWarning: The `probability` parameter was deprecated in 1.9 and will be removed in version 1.11. Use `CalibratedClassifierCV(SVC(), ensemble=False)` instead of `SVC(probability=True)`
#   warnings.warn(
# SVC(C=0.1, degree=2, kernel='sigmoid', probability=True, random_state=42)

# %%
svc_pred = svc.predict(x_test)
svc_pred_train = svc.predict(x_train)
svc_pred_proba = svc.predict_proba(x_test)[:, 1]

# %% [markdown]
# # checking overfitting

# %%
print("model accuracy",accuracy_score(y_test, svc_pred))
print("train accuracy",accuracy_score(y_train, svc_pred_train))
# Out:
# model accuracy 0.9711615487316422
# train accuracy 0.9711615487316422

# %%
print("Classification Report \n",classification_report(y_test,svc_pred))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      3637
#            1       0.00      0.00      0.00       108
#
#     accuracy                           0.97      3745
#    macro avg       0.49      0.50      0.49      3745
# weighted avg       0.94      0.97      0.96      3745
# C:\Users\Mahmoud\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Mahmoud\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Mahmoud\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
print("R2 Score: ",r2_score(y_test,svc_pred))
# Out:
# R2 Score:  -0.029694803409403336

# %%
print("ROC-AUC: ",roc_auc_score(y_test,svc_pred_proba))
# Out:
# ROC-AUC:  0.5321719162109593

# %%
RocCurveDisplay.from_predictions(y_test, svc_pred_proba, name='SVC')
plt.plot([0,1],[0,1],'k--', alpha=0.3)
plt.title('ROC Curve - SVC')
plt.show()

# %%
cm = confusion_matrix(y_test, svc_pred)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Fraud']).plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix - SVC')
plt.show()

# %% [markdown]
# # Grid Search

# %%
param ={'kernel':['sigmoid','rbf','poly'],'C':[0.1,1,4],'degree':[2,3,4],'random_state':[42]}
grid = GridSearchCV(SVC(),param)
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 4], 'degree': [2, 3, 4],
#                          'kernel': ['sigmoid', 'rbf', 'poly'],
#                          'random_state': [42]})

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'degree': 2, 'kernel': 'sigmoid', 'random_state': 42}

# %%
grid.best_score_
# Out:
# np.float64(0.9711615487316422)

# %% [markdown]
# # Logistic Regression Model

# %%
logistic_model = LogisticRegression()
logistic_model.fit(x_train,y_train)
# Out:
# C:\Users\Mahmoud\AppData\Roaming\Python\Python314\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logistic_pred__train = logistic_model.predict(x_train)

# %%
logistic_pred = logistic_model.predict(x_test)

# %%
logistic_pred_proba = logistic_model.predict_proba(x_test)[:, 1]

# %% [markdown]
# # checking overfitting

# %%
print("Model Accuracy :", accuracy_score(y_test, logistic_pred))
print("Train Accuracy :", accuracy_score(y_train,logistic_pred__train ))
# Out:
# Model Accuracy : 0.9949265687583445
# Train Accuracy : 0.9935914552736983

# %%
print("Classification Report \n",classification_report(y_test,logistic_pred))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3637
#            1       0.98      0.84      0.91       108
#
#     accuracy                           0.99      3745
#    macro avg       0.99      0.92      0.95      3745
# weighted avg       0.99      0.99      0.99      3745

# %%
print("R2 Score: ",r2_score(y_test,logistic_pred))
# Out:
# R2 Score:  0.8188499882890865

# %%
print("ROC-AUC: ",roc_auc_score(y_test,logistic_pred_proba))
# Out:
# ROC-AUC:  0.9593173046568703

# %%
RocCurveDisplay.from_predictions(y_test, logistic_pred_proba, name='Logistic Regression')
plt.plot([0,1],[0,1],'k--', alpha=0.3)
plt.title('ROC Curve - Logistic Regression')
plt.show()

# %%
cm = confusion_matrix(y_test, logistic_pred)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Fraud']).plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()

# %% [markdown]
# # KNN

# %%
knn= KNeighborsClassifier(n_neighbors=2,weights="distance")
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2, weights='distance')

# %%
knn_pred = knn.predict(x_test)

# %%
knn_train = knn.predict(x_train)

# %%
knn_pred_proba = knn.predict_proba(x_test)[:, 1]

# %% [markdown]
# # Checking overfitting

# %%
print("model accuracy :",accuracy_score(y_test,knn_pred))
print("train accuracy :",accuracy_score(y_train,knn_train))
# Out:
# model accuracy : 0.9580774365821095
# train accuracy : 1.0

# %%
print("classification Report : \n",classification_report(y_test,knn_pred))
# Out:
# classification Report :
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      3637
#            1       0.24      0.21      0.23       108
#
#     accuracy                           0.96      3745
#    macro avg       0.61      0.60      0.60      3745
# weighted avg       0.96      0.96      0.96      3745

# %%
print("R2 Score: ",r2_score(y_test,knn_pred))
# Out:
# R2 Score:  -0.49687114940070654

# %%
print("ROC-AUC: ",roc_auc_score(y_test,knn_pred_proba))
# Out:
# ROC-AUC:  0.6076640291652665

# %%
RocCurveDisplay.from_predictions(y_test, knn_pred_proba, name='KNN')
plt.plot([0,1],[0,1],'k--', alpha=0.3)
plt.title('ROC Curve - KNN')
plt.show()

# %%
cm = confusion_matrix(y_test, knn_pred)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Fraud']).plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix - KNN')
plt.show()

# %% [markdown]
# # Decision Tree

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
dt_pred = dt.predict(x_test)

# %%
dt_train = dt.predict(x_train)

# %%
dt_pred_proba = dt.predict_proba(x_test)[:, 1]

# %% [markdown]
# # Checking overfitting

# %%
print("model accuracy :",accuracy_score(y_test,dt_pred))
print("train accuracy :",accuracy_score(y_train,dt_train))
# Out:
# model accuracy : 0.9890520694259012
# train accuracy : 1.0

# %%
print("classification Report : \n",classification_report(y_test,dt_pred))
# Out:
# classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      3637
#            1       0.77      0.88      0.82       108
#
#     accuracy                           0.99      3745
#    macro avg       0.88      0.94      0.91      3745
# weighted avg       0.99      0.99      0.99      3745

# %%
print("R2 Score: ",r2_score(y_test,dt_pred))
# Out:
# R2 Score:  0.609097343150134

# %%
print("ROC-AUC: ",roc_auc_score(y_test,dt_pred_proba))
# Out:
# ROC-AUC:  0.9359654884469294

# %%
RocCurveDisplay.from_predictions(y_test, dt_pred_proba, name='Decision Tree')
plt.plot([0,1],[0,1],'k--', alpha=0.3)
plt.title('ROC Curve - Decision Tree')
plt.show()

# %%
cm = confusion_matrix(y_test, dt_pred)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Fraud']).plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix - Decision Tree')
plt.show()

# %%
importances_dt = pd.Series(dt.feature_importances_, index=x_train.columns).sort_values(ascending=False)
importances_dt.head(10).plot(kind='barh', figsize=(8,6), color='teal')
plt.title('Top 10 Feature Importances - Decision Tree')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestClassifier(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_pred = rf.predict(x_test)

# %%
rf_train = rf.predict(x_train)

# %%
rf_pred_proba = rf.predict_proba(x_test)[:, 1]

# %% [markdown]
# # Checking overfitting

# %%
print("model accuracy :",accuracy_score(y_test,rf_pred))
print("train accuracy :",accuracy_score(y_train,rf_train))
# Out:
# model accuracy : 0.9959946595460614
# train accuracy : 0.9999109924343569

# %%
print("classification Report : \n",classification_report(y_test,rf_pred))
# Out:
# classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3637
#            1       0.98      0.88      0.93       108
#
#     accuracy                           1.00      3745
#    macro avg       0.99      0.94      0.96      3745
# weighted avg       1.00      1.00      1.00      3745

# %%
print("R2 Score: ",r2_score(y_test,rf_pred))
# Out:
# R2 Score:  0.8569868328598051

# %%
print("ROC-AUC: ",roc_auc_score(y_test,rf_pred_proba))
# Out:
# ROC-AUC:  0.9697107404352387

# %%
RocCurveDisplay.from_predictions(y_test, rf_pred_proba, name='Random Forest')
plt.plot([0,1],[0,1],'k--', alpha=0.3)
plt.title('ROC Curve - Random Forest')
plt.show()

# %%
cm = confusion_matrix(y_test, rf_pred)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Fraud']).plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix - Random Forest')
plt.show()

# %%
importances_rf = pd.Series(rf.feature_importances_, index=x_train.columns).sort_values(ascending=False)
importances_rf.head(10).plot(kind='barh', figsize=(8,6), color='steelblue')
plt.title('Top 10 Feature Importances - Random Forest')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # Extra Tree

# %%
et = ExtraTreesClassifier(n_estimators=150,random_state=42)
et.fit(x_train,y_train)
# Out:
# ExtraTreesClassifier(n_estimators=150, random_state=42)

# %%
et_pred = et.predict(x_test)

# %%
et_train = et.predict(x_train)

# %%
et_pred_proba = et.predict_proba(x_test)[:, 1]

# %% [markdown]
# # Checking overfitting

# %%
print("model accuracy :",accuracy_score(y_test,et_pred))
print("train accuracy :",accuracy_score(y_train,et_train))
# Out:
# model accuracy : 0.9959946595460614
# train accuracy : 1.0

# %%
print("classification Report : \n",classification_report(y_test,et_pred))
# Out:
# classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3637
#            1       0.98      0.88      0.93       108
#
#     accuracy                           1.00      3745
#    macro avg       0.99      0.94      0.96      3745
# weighted avg       1.00      1.00      1.00      3745

# %%
print("R2 Score: ",r2_score(y_test,et_pred))
# Out:
# R2 Score:  0.8569868328598051

# %%
print("ROC-AUC: ",roc_auc_score(y_test,et_pred_proba))
# Out:
# ROC-AUC:  0.9730789010071386

# %%
RocCurveDisplay.from_predictions(y_test, et_pred_proba, name='Extra Tree')
plt.plot([0,1],[0,1],'k--', alpha=0.3)
plt.title('ROC Curve - Extra Tree')
plt.show()

# %%
cm = confusion_matrix(y_test, et_pred)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Fraud']).plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix - Extra Tree')
plt.show()

# %%
importances_et = pd.Series(et.feature_importances_, index=x_train.columns).sort_values(ascending=False)
importances_et.head(10).plot(kind='barh', figsize=(8,6), color='darkorange')
plt.title('Top 10 Feature Importances - Extra Tree')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # Models Comparison

# %%
models_preds = {
    'SVC': svc_pred,
    'Logistic Regression': logistic_pred,
    'KNN': knn_pred,
    'Decision Tree': dt_pred,
    'Random Forest': rf_pred,
    'Extra Tree': et_pred
}

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
axes = axes.flatten()

for ax, (name, pred) in zip(axes, models_preds.items()):
    cm = confusion_matrix(y_test, pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Fraud'])
    disp.plot(ax=ax, cmap='Blues', colorbar=False, values_format='d')
    ax.set_title(name)

plt.tight_layout()
plt.suptitle('Confusion Matrices - All Models', y=1.02, fontsize=16)
plt.show()

# %%
predictions = {
    'Logistic Regression': logistic_pred_proba,
    'SVC': svc_pred_proba,
    'Random Forest': rf_pred_proba,
    'KNN': knn_pred_proba,
    'Decision Tree': dt_pred_proba,
    'Extra Tree': et_pred_proba
}

fig, ax = plt.subplots(figsize=(8, 6))

for name, y_proba in predictions.items():
    RocCurveDisplay.from_predictions(y_test, y_proba, name=name, ax=ax)

plt.title('ROC Curve Comparison - All Models')
plt.grid(alpha=0.3)
plt.show()

# %%
models_results = {
    'SVC': {'pred': svc_pred, 'train_pred': svc_pred_train, 'proba': svc_pred_proba},
    'Logistic Regression': {'pred': logistic_pred, 'train_pred': logistic_pred__train, 'proba': logistic_pred_proba},
    'KNN': {'pred': knn_pred, 'train_pred': knn_train, 'proba': knn_pred_proba},
    'Decision Tree': {'pred': dt_pred, 'train_pred': dt_train, 'proba': dt_pred_proba},
    'Random Forest': {'pred': rf_pred, 'train_pred': rf_train, 'proba': rf_pred_proba},
    'Extra Tree': {'pred': et_pred, 'train_pred': et_train, 'proba': et_pred_proba}
}
comparison = []
for name, res in models_results.items():
    test_acc = accuracy_score(y_test, res['pred'])
    train_acc = accuracy_score(y_train, res['train_pred'])
    precision = precision_score(y_test, res['pred'])
    recall = recall_score(y_test, res['pred'])
    f1 = f1_score(y_test, res['pred'])
    r2 = r2_score(y_test, res['pred'])
    roc_auc = roc_auc_score(y_test, res['proba'])
    overfit_gap = train_acc - test_acc

    comparison.append({
        'Model': name,
        'Test Accuracy': test_acc,
        'Train Accuracy': train_acc,
        'Overfitting Gap': overfit_gap,
        'Precision (Fraud)': precision,
        'Recall (Fraud)': recall,
        'F1-Score (Fraud)': f1,
        'R2 Score': r2,
        'ROC-AUC': roc_auc
    })
comparison_df = pd.DataFrame(comparison)
comparison_df = comparison_df.sort_values(by='ROC-AUC', ascending=False).reset_index(drop=True)
comparison_df
# Out:
# C:\Users\Mahmoud\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#                  Model  Test Accuracy  Train Accuracy  Overfitting Gap  \
# 0           Extra Tree       0.995995        1.000000         0.004005
# 1        Random Forest       0.995995        0.999911         0.003916
# 2  Logistic Regression       0.994927        0.993591        -0.001335
# 3        Decision Tree       0.989052        1.000000         0.010948
# 4                  KNN       0.958077        1.000000         0.041923
# 5                  SVC       0.971162        0.971162         0.000000
#
#    Precision (Fraud)  Recall (Fraud)  F1-Score (Fraud)  R2 Score   ROC-AUC
# 0           0.979381        0.879630          0.926829  0.856987  0.973079
# 1           0.979381        0.879630          0.926829  0.856987  0.969711
# 2           0.978495        0.842593          0.905473  0.818850  0.959317
# 3           0.772358        0.879630          0.822511  0.609097  0.935965
# 4           0.242105        0.212963          0.226601 -0.496871  0.607664
# 5           0.000000        0.000000          0.000000 -0.029695  0.532172

# %%
comparison_df.set_index('Model')[['Test Accuracy', 'Precision (Fraud)', 'Recall (Fraud)', 'ROC-AUC']].plot(
    kind='bar', figsize=(12,6)
)
plt.title('Model Comparison - Accuracy vs Recall vs ROC-AUC')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.grid(alpha=0.3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
